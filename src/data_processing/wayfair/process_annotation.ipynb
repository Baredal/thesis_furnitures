# %%
import json
from pathlib import Path

# %%
BASE_DIR = Path().cwd().parents[2]
PROCESSED_DATA_DIR = BASE_DIR / "data" / "processed_data" / "wayfair"

# %%
scenes_processed = 0

for scene_folder in sorted(PROCESSED_DATA_DIR.glob("wayfair_[0-9][0-9][0-9][0-9]")):
    if not scene_folder.is_dir():
        continue

    annotation_path = scene_folder / "annotations.json"
    
    if annotation_path.exists():
        with open(annotation_path, "r", encoding="utf-8") as f:
            annotation = json.load(f)
    else:
        annotation = {
            "scene_name": scene_folder.name,
            "furnitures": []
        }
    
    # Convert all categories to lowercase
    for furniture in annotation.get("furnitures", []):
        if "category" in furniture:
            cat = furniture["category"].lower()
            if cat == "chair#stool":
                cat = "chair_stool"
            furniture["category"] = cat
    
    with open(annotation_path, "w", encoding="utf-8") as f:
        json.dump(annotation, f, ensure_ascii=False, indent=2)
    
    scenes_processed += 1
    print(f"{scene_folder.name}")

print(f"Total scenes processed: {scenes_processed}")
# Out:
# wayfair_0000
# wayfair_0001
# wayfair_0002
# wayfair_0003
# wayfair_0004
# wayfair_0005
# wayfair_0006
# wayfair_0007
# wayfair_0008
# wayfair_0009
# wayfair_0010
# wayfair_0011
# wayfair_0012
# wayfair_0013
# wayfair_0014
# wayfair_0015
# wayfair_0016
# wayfair_0017
# wayfair_0018
# wayfair_0019
# wayfair_0020
# wayfair_0021
# wayfair_0022
# wayfair_0023
# wayfair_0024
# wayfair_0025
# wayfair_0026
# wayfair_0027
# wayfair_0028
# wayfair_0029
# wayfair_0030
# wayfair_0031
# wayfair_0032
# wayfair_0033
# wayfair_0034
# wayfair_0035
# wayfair_0036
# wayfair_0037
# wayfair_0038
# wayfair_0039
# wayfair_0040
# wayfair_0041
# wayfair_0042
# wayfair_0043
# wayfair_0044
# wayfair_0045
# wayfair_0046
# wayfair_0047
# wayfair_0048
# wayfair_0049
# wayfair_0050
# wayfair_0051
# wayfair_0052
# wayfair_0053
# wayfair_0054
# wayfair_0055
# wayfair_0056
# wayfair_0057
# wayfair_0058
# Total scenes processed: 59
